# %%
import pandas as pd

# %%
tabla = "tabla.html"
df = pd.read_html(tabla)[0]
df.head()
# Out:
#                   Álbum      Canción 1           Canción 2  \
# 0   From Mars to Sirius  Flying Whales            Backbone
# 1  The Way of All Flesh        Vacuity  Adoration for None
# 2                 Magma       Stranded             Silvera
#
#                          Canción 3
# 0                     Ocean Planet
# 1  Heaviest Matter of the Universe
# 2                        Only Pain

# %%
tablas = pd.read_html("tabla.html")
primera_banda = tablas[0]
segunda_banda = tablas[1]
print(primera_banda)
print(segunda_banda)
# Out:
#                   Álbum      Canción 1           Canción 2  \
# 0   From Mars to Sirius  Flying Whales            Backbone
# 1  The Way of All Flesh        Vacuity  Adoration for None
# 2                 Magma       Stranded             Silvera
#
#                          Canción 3
# 0                     Ocean Planet
# 1  Heaviest Matter of the Universe
# 2                        Only Pain
#                 Álbum             Canción 1                Canción 2  \
# 0   Master of Puppets               Battery        Master of Puppets
# 1     The Black Album         Enter Sandman             Sad But True
# 2  Ride the Lightning  Fight Fire with Fire  For Whom the Bell Tolls
#
#                    Canción 3
# 0  Welcome Home (Sanitarium)
# 1             The Unforgiven
# 2             Creeping Death

# %%
tablas = pd.read_html("datos_html_festival.html")
print("tablas detectadas; ", len(tablas))
for i, tabla in enumerate(tablas, start=1):
    print(i)
    display(tabla.head())
# Out:
# tablas detectadas;  2
# 1
#   escenario         artista   hora       genero
# 0     Solar       Luna Byte  18:30  Electro Pop
# 1      Neón  Los Dataframes  19:15        Indie
# 2    Aurora     SQL Sisters  20:00        Synth
# 3     Solar     Pandas Crew  21:00         Funk
# 4      Neón    Null Hunters  22:10         Rock
# 2
#             producto   categoria  precio_eur  unidades
# 0      Camiseta Glow        Ropa          20        45
# 1     Tote Bag Pixel  Accesorios          12        60
# 2       Sticker Pack  Accesorios           5       120
# 3        Gorra Night        Ropa          15        38
# 4  Vaso Reutilizable       Hogar           8        72
